# %% [markdown]
# # How are in-demand skills trending for Data Analysts

# %% [markdown]
# ### Methodology
#
# 1. Aggregate skill counts monthly
# 2. Re-analyze based on percentage of total jobs
# 3. Plot the monthly skill demand

# %%
# Importing Libraries
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt

#Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_Canada = df[(df['job_title'] == 'Data Analyst') &  (df['job_country'] == 'Canada')].copy()

# %%
df_DA_Canada['job_posted_month_no'] = df_DA_Canada['job_posted_date'].dt.month

# %%
df_DA_Canada_explode = df_DA_Canada.explode('job_skills')

# %%
df_DA_Canada_pivot = df_DA_Canada_explode.pivot_table(index='job_posted_month_no', columns='job_skills',aggfunc='size',fill_value=0)

# %%
df_DA_Canada_pivot.loc['Total'] = df_DA_Canada_pivot.sum()

df_DA_Canada_pivot = df_DA_Canada_pivot[df_DA_Canada_pivot.loc['Total'].sort_values(ascending=False).index]

df_DA_Canada_pivot = df_DA_Canada_pivot.drop('Total')

df_DA_Canada_pivot
# Out:
# job_skills           sql  python  excel  tableau  power bi   r  sas  azure  \
# job_posted_month_no
# 1                     43      33     24       22        19  15    6      2
# 2                     24      15     10        3        12   8    0      8
# 3                     16      11     10        6         5   7    0      3
# 4                     14       6      5        5         3   1    2      2
# 5                     25      17     20       14        12   8    6      6
# 6                     26      14     21       12         7   9    8      1
# 7                     24      14     18       14        10  10    2      5
# 8                     23      15     10       10        10   6    6      4
# 9                     36      19     17       18        16  12    6      7
# 10                    33      15     27       14        13  13    6      3
# 11                    26      19     16       15        16  10    4      4
# ...

# %%
DA_totals = df_DA_Canada.groupby('job_posted_month_no').size()

# %%
df_DA_Canada_percent = df_DA_Canada_pivot.div(DA_totals/100,axis=0)

# %%
# changes month number to month name
df_DA_Canada_percent = df_DA_Canada_percent.reset_index()
df_DA_Canada_percent['job_posted_month'] = df_DA_Canada_percent['job_posted_month_no'].apply(lambda x: pd.to_datetime(x,format='%m').strftime('%b'))
df_DA_Canada_percent = df_DA_Canada_percent = df_DA_Canada_percent.set_index('job_posted_month')
df_DA_Canada_percent = df_DA_Canada_percent.drop(columns='job_posted_month_no')

df_DA_Canada_percent
# Out:
# job_skills              sql     python      excel    tableau   power bi  \
# job_posted_month
# Jan               66.153846  50.769231  36.923077  33.846154  29.230769
# Feb               68.571429  42.857143  28.571429   8.571429  34.285714
# Mar               51.612903  35.483871  32.258065  19.354839  16.129032
# Apr               53.846154  23.076923  19.230769  19.230769  11.538462
# May               67.567568  45.945946  54.054054  37.837838  32.432432
# Jun               61.904762  33.333333  50.000000  28.571429  16.666667
# Jul               60.000000  35.000000  45.000000  35.000000  25.000000
# Aug               58.974359  38.461538  25.641026  25.641026  25.641026
# Sep               75.000000  39.583333  35.416667  37.500000  33.333333
# Oct               56.896552  25.862069  46.551724  24.137931  22.413793
# Nov               52.000000  38.000000  32.000000  30.000000  32.000000
# Dec               59.259259  35.185185   9.259259  35.185185  16.666667
#
# ...

# %%
df_plot = df_DA_Canada_percent.iloc[:,:5]

sns.lineplot(data=df_plot,dashes=False,palette='tab10')
sns.set_theme(style='ticks')
sns.despine()

plt.title('Trending Top Skills for Data Analysts in Canada')
plt.ylabel('Likelihood in Job Posting')
plt.xlabel('2023')
plt.legend().remove()

from matplotlib.ticker import PercentFormatter
ax = plt.gca()
ax.yaxis.set_major_formatter(PercentFormatter(decimals=0))


offsets = [0.5, 2, 1, -1, 0]   # tweak these as needed

for i in range(5):
    plt.text(
        11.2,
        df_plot.iloc[-1, i] + offsets[i],
        df_plot.columns[i],
        va='center'
    )

"""
for i in range(5):
    plt.text(11.2,df_plot.iloc[-1,i],df_plot.columns[i])
"""
# Out:
# '\nfor i in range(5):\n    plt.text(11.2,df_plot.iloc[-1,i],df_plot.columns[i])\n'
